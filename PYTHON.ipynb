# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilo-15/python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** ✝️ ⚽ 💪
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ano = "II"
# print(ano, "competição de programação dá Start")

# %% [markdown]
# #**Aula 2** 🥷 ⚪ ⚫

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_Ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_Ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# #AULA 3 ⚓ ✒ ♟

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigos = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigos

print("João recebeu", figurinhas_joao, "figurinhas")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-678850604.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3 figurinhas_amigos = total_de_figurinhas // (numero_de_amigos + 2)
#       4 figurinhas_joao = 2 * figurinhas_amigos
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# ## **Aula**  **4**   ✈ 🇩 😢

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")


numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
